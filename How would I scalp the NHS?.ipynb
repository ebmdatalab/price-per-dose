# %%
import pandas as pd

from IPython.core.display import display, HTML


month = '2016-09-01'

# %% [markdown]
# # How could we scalp the NHS?
#
# Anything not listed in the Drug Tariff ("NP8" - Not Part 8) can be supplied by a dispensing contractor at whatever price they find. They can then pass their invoice on to the NHS.
#
# Some pharma companies specialise in selling pills at rip-off prices (e.g. £90 for a packet of cod liver oil capsules, as exposed in [this Telegraph article from 2013](http://www.telegraph.co.uk/news/health/news/10181169/Pricing-scandal-sees-NHS-pay-89-for-accessible-cod-liver-oil-capsules.html)) to the contractor, who then passes on the cost to the NHS. Separately, the pharma company has a contract with the pharmacy to pay them the equivalent of (say) £45 per packet "commission". As one happy pharmacist [said in an online forum](http://www.pharmacy-forum.co.uk/showthread.php?t=10802):
#
# > There's also NP8 (non part VIII drugs)..these are drugs not listed so the price paid is whatever it costs you to buy. Now some wholesalers will say X amount for an NP8 drug then give you 50/60/70 or even 80% off in a legally round about way- thats a ton of margin right there because you claim say £100 when actually you've only paid £20. Think Tramadol M/R formulations.
#
# Therefore, if I was a Black Hat Pharma company, I would look for drugs which:
#
# * Are not in the Tariff;
# * Are generically prescribed;
# * Are prescribed in relatively high quantities;
# * Are not already subject to fleecing by my competitors
#
# We can use a coefficient of deviation to find things which do (or don't) already have high variance.

# %%
sql = """

WITH np8_drugs AS (SELECT
  p.bnf_code,
  p.bnf_name,
  sum(quantity) as quantity,
  sum(actual_cost) as actual_cost,
  IEEE_DIVIDE(stddev_pop(IEEE_DIVIDE(actual_cost, quantity)), avg(IEEE_DIVIDE(actual_cost,quantity))) as coefficient_of_deviation
FROM
  ebmdatalab.hscic.prescribing AS p
LEFT JOIN
  ebmdatalab.hscic.tariff t
ON
  t.bnf_code = p.bnf_code
  AND TIMESTAMP(t.date) = p.month
WHERE
  p.month = TIMESTAMP('"""+month+"""') 
AND 
  category IS NULL -- not in the tariff
AND p.bnf_code LIKE '_________AA%' -- generically prescribed
AND p.bnf_code NOT LIKE '19%' -- specials
GROUP BY p.bnf_code, p.bnf_name)

SELECT * 
FROM 
  np8_drugs 
WHERE actual_cost > 2000 -- relatively high quantities
ORDER BY
  coefficient_of_deviation ASC -- things with least variability first (no-one else is on it yet)

"""
df = pd.io.gbq.read_gbq(sql, project_id="ebmdatalab", verbose=False, dialect='standard')

# %%
#df.head(10)
display(HTML(df.to_html(formatters={'actual_cost': '£{:,.2f}'.format}, max_rows=10)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bnf_code</th>
#       <th>bnf_name</th>
#       <th>quantity</th>
#       <th>actual_cost</th>
#       <th>coefficient_of_deviation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1308010Z0AAAAAA</td>
#       <td>Ingenol Mebutate_Gel 150mcg/g</td>
#       <td>905</td>
#       <td>£54,508.88</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1308010Z0AAABAB</td>
#       <td>Ingenol Mebutate_Gel 500mcg/g</td>
#       <td>6</td>
#       <td>£8,371.70</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0109010G0AAABAB</td>
#       <td>Chenodeoxycholic Acid_Cap 250mg</td>
#       <td>60</td>
#       <td>£2,590.48</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0602010V0AADFDF</td>
#       <td>Levothyrox Sod_Liq Spec 300mcg/5ml</td>
#       <td>1200</td>
#       <td>£2,254.72</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0908010E0AAADAD</td>
#       <td>Mercaptamine_Cap G/R 75mg</td>
#       <td>250</td>
#       <td>£3,890.80</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1044</th>
#       <td>0901020D0AAAFAF</td>
#       <td>Cyanocobalamin_Tab 1mg</td>
#       <td>7893</td>
#       <td>£8,398.90</td>
#       <td>2.537117</td>
#     </tr>
#     <tr>
#       <th>1045</th>
#       <td>0906040G0AAEAEA</td>
#       <td>Colecal_Cap 5 000u</td>
#       <td>14454</td>
#       <td>£5,504.63</td>
#       <td>2.869920</td>
#     </tr>
#     <tr>
#       <th>1046</th>
#       <td>091200000AAEEEE</td>
#       <td>Glucosamine + Chond_Cap 400mg/100mg</td>
#       <td>12180</td>
#       <td>£3,142.78</td>
#       <td>2.969154</td>
#     </tr>
#     <tr>
#       <th>1047</th>
#       <td>0906040N0AAEWEW</td>
#       <td>Ergocalciferol_Tab 12.5mcg</td>
#       <td>16016</td>
#       <td>£3,731.40</td>
#       <td>3.177512</td>
#     </tr>
#     <tr>
#       <th>1048</th>
#       <td>0906040G0AADBDB</td>
#       <td>Colecal_Tab 2 000u</td>
#       <td>31962</td>
#       <td>£8,807.21</td>
#       <td>3.795979</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It might be easier for us to scalp where the price per dose is currently relatively low. Let's only look at presentations where a does is less than £1, then put the ones with the greatest monthly cost to the NHS at the top.

# %%
df.query('(actual_cost / quantity < 1.0) & coefficient_of_deviation < 0.01').sort_values('actual_cost', ascending=False).head()
# Out:
#             bnf_code                                  bnf_name  quantity  \
# 268  0601023AFAAABAB  Linagliptin/Metformin_Tab 2.5mg/1g          178499
# 156  0408010D0AAAEAE  Oxcarbazepine_Oral Susp 300mg/5ml S/F       222852
# 82   1305020D0AAAIAI  Calcipotriol/Betameth_Foam 50mcg/0.5mg/g     60720
# 245  0802010M0AAAJAJ  Mycophenolate Mofetil_Oral Susp 1g/5mlSF     52150
# 75   0408010AFAAADAD  Rufinamide_Oral Susp 200mg/5ml S/F          122360
#
#      actual_cost  coefficient_of_deviation
# 268     98314.04                  0.003241
# 156     40443.25                  0.000571
# 82      37210.98                  0.000064
# 245     31800.55                  0.002465
# 75      23342.00                  0.000058

# %% [markdown]
# # Where is scalping most likely to be happening now?
#
# We can reverse the logic to find the presentations most likely to be subject to scalping right now:

# %%
sql = """

WITH np8_drugs AS (SELECT
  p.bnf_code,
  p.bnf_name,
  sum(quantity) as quantity,
  sum(actual_cost) as actual_cost,
  IEEE_DIVIDE(stddev_pop(IEEE_DIVIDE(actual_cost, quantity)), avg(IEEE_DIVIDE(actual_cost,quantity))) as coefficient_of_deviation
FROM
  ebmdatalab.hscic.prescribing AS p
LEFT JOIN
  ebmdatalab.hscic.tariff t
ON
  t.bnf_code = p.bnf_code
  AND TIMESTAMP(t.date) = p.month

WHERE
  p.month = TIMESTAMP('"""+month+"""') 
AND 
  category IS NULL -- not in the tariff
AND p.bnf_code LIKE '_________AA%' -- generically prescribed
AND p.bnf_code NOT LIKE '19%' -- specials
GROUP BY p.bnf_code, p.bnf_name),

top_drugs AS (
SELECT np8_drugs.*, bnf.supplier, bnf.tariff_category, bnf.pack_size_count, bnf.bioequivalence, bnf.route
FROM 
  np8_drugs 
LEFT JOIN ebmdatalab.hscic.super_bnf AS bnf
ON bnf.bnf_code = np8_drugs.bnf_code

WHERE actual_cost > 2000 -- relatively high quantities
ORDER BY
  coefficient_of_deviation DESC -- things with most variability first
LIMIT 100
)

select * 
FROM top_drugs 
"""
df2 = pd.io.gbq.read_gbq(sql, project_id="ebmdatalab", verbose=False, dialect='standard')

# %%
df2[df2.bnf_code.str.startswith('03')].head()
# Out:
#            bnf_code                                  bnf_name  quantity  \
# 77  0304010N0AAAGAG  Diphenhydramine HCl_Tab 25mg                 41857
#
#     actual_cost  coefficient_of_deviation                    supplier  \
# 77      6097.43                  1.674817  Galpharm International Ltd
#
#    tariff_category  pack_size_count bioequivalence        route
# 77            None               45           True  tablet.oral

# %%
sql = """

WITH np8_drugs AS (SELECT
  p.bnf_code,
  p.bnf_name,
  sum(quantity) as quantity,
  sum(actual_cost) as actual_cost,
  IEEE_DIVIDE(stddev_pop(IEEE_DIVIDE(actual_cost, quantity)), avg(IEEE_DIVIDE(actual_cost,quantity))) as coefficient_of_deviation
FROM
  ebmdatalab.hscic.prescribing AS p
LEFT JOIN
  ebmdatalab.hscic.tariff t
ON
  t.bnf_code = p.bnf_code
  AND TIMESTAMP(t.date) = p.month

WHERE
  p.month = TIMESTAMP('"""+month+"""') 
AND 
  category IS NULL -- not in the tariff
AND p.bnf_code LIKE '_________AA%' -- generically prescribed
AND p.bnf_code NOT LIKE '19%' -- specials
GROUP BY p.bnf_code, p.bnf_name),

top_drugs AS (
SELECT np8_drugs.*, bnf.supplier, bnf.tariff_category, bnf.pack_size_count, bnf.bioequivalence, bnf.route
FROM 
  np8_drugs 
LEFT JOIN ebmdatalab.hscic.super_bnf AS bnf
ON bnf.bnf_code = np8_drugs.bnf_code

WHERE actual_cost > 2000 -- relatively high quantities
ORDER BY
  coefficient_of_deviation DESC -- things with most variability first
LIMIT 100
)

select supplier, count(*) as count, sum(actual_cost) as total_cost, avg(pack_size_count) as avg_pack_size
FROM top_drugs 
GROUP BY supplier
ORDER BY total_cost DESC
"""
df3 = pd.io.gbq.read_gbq(sql, project_id="ebmdatalab", verbose=False, dialect='standard')

# %%
df3.head(20)
# Out:
#                             supplier  count  total_cost  avg_pack_size
# 0                         Pfizer Ltd      4   804407.92       4.500000
# 1          A A H Pharmaceuticals Ltd      4   712599.56      61.250000
# 2            Solgar Vitamin and Herb      5   370748.38     112.800000
# 3                      Special Order     33   264505.46      10.878788
# 4                    Kyowa Kirin Ltd      1   118205.80      10.000000
# 5               Chugai Pharma UK Ltd      2   107039.22      18.500000
# 6        Intrapharm Laboratories Ltd      1    81556.52      68.000000
# 7                 Arjun Products Ltd      1    79850.97      15.000000
# 8                      HealthAid Ltd      5    64860.88      96.400000
# 9            Lamberts Healthcare Ltd      2    51614.85      55.000000
# 10         Molnlycke Health Care Ltd      1    46911.82      39.000000
# 11                 Imported (Canada)      1    44510.11       6.000000
# 12                            Sanofi      3    40023.03      10.333333
# 13             The Boots Company Plc      1    38551.00     119.000000
# 14                    UCB Pharma Ltd      1    33637.81       8.000000
# 15            BR Pharmaceuticals Ltd      1    31362.67     312.000000
# 16                Roche Products Ltd      1    29985.03       6.000000
# 17             Synergy Biologics Ltd      2    28233.62      12.000000
# 18  AM Distributions (Yorkshire) Ltd      1    25133.19       2.000000
# 19         Focus Pharmaceuticals Ltd      1    22680.36      66.000000

# %%
df2.query('bnf_code =="0302000C0AABEBE"')
df2.query('(actual_cost / quantity < 1.0) & coefficient_of_deviation > 0.1').sort_values('actual_cost', ascending=False).head()
# Out:
#            bnf_code                                  bnf_name  quantity  \
# 31  0906040G0AABHBH  Colecal_Cap 1 000u                          497926
# 59  0604020K0AABMBM  Testosterone_Gel 2% (10mg per actuation)    225000
# 16  0906040G0AABIBI  Colecal_Cap 400u                            255240
# 86  0206010K0AAAGAG  Isosorbide Mononit_Tab 40mg M/R             157165
# 57  0905013G0AAAYAY  Mag Glycerophos_Tab Chble 97.2mg S/F         93326
#
#     actual_cost  coefficient_of_deviation                     supplier  \
# 31    257550.94                  1.590396      Solgar Vitamin and Herb
# 59    118205.80                  1.008506              Kyowa Kirin Ltd
# 16     95559.03                  1.990893      Solgar Vitamin and Herb
# 86     81556.52                  0.934972  Intrapharm Laboratories Ltd
# 57     79850.97                  2.210185           Arjun Products Ltd
#
#    tariff_category  pack_size_count bioequivalence  \
# 31             3.0              418           True
# 59             3.0               10           True
# 16            None               70           True
# 86             3.0               68           True
# 57            None               15           True
#
#                           route
# 31                 capsule.oral
# 59                gel.cutaneous
# 16                 capsule.oral
# 86  tabletmodified-release.oral
# 57                  tablet.oral

# %%
df2.query('supplier == "A A H Pharmaceuticals Ltd"')
# Out:
#            bnf_code                                  bnf_name  quantity  \
# 4   1501041T0AAABAB  Midazolam HCl_Inj 2mg/ml 5ml Amp              2395
# 58  0407010Q0AAAAAA  Co-Proxamol_Tab 32.5mg/325mg                659538
# 84  1501041T0AAASAS  Midazolam HCl_Inj 1mg/ml 5ml Amp              6953
# 99  1108010K0AAAAAA  Sod Chlor_Eye Dps 0.9%                        1060
#
#     actual_cost  coefficient_of_deviation                   supplier  \
# 4       2373.43                  1.175262  A A H Pharmaceuticals Ltd
# 58    702718.55                  1.575012  A A H Pharmaceuticals Ltd
# 84      4178.51                  1.318242  A A H Pharmaceuticals Ltd
# 99      3329.07                  1.587540  A A H Pharmaceuticals Ltd
#
#    tariff_category  pack_size_count bioequivalence  \
# 4             None               68           True
# 58            None              105           True
# 84            None               56           True
# 99            None               16           True
#
#                               route
# 4              solutionenema.rectal
# 58                      tablet.oral
# 84  solutioninjection.intramuscular
# 99         solutiondrops.ophthalmic

# %%
df2.query('supplier == "Solgar Vitamin and Herb"')
# Out:
#            bnf_code                                  bnf_name  quantity  \
# 16  0906040G0AABIBI  Colecal_Cap 400u                            255240
# 31  0906040G0AABHBH  Colecal_Cap 1 000u                          497926
# 39  0906040G0AADWDW  Colecal_Cap 2 200u                            9154
# 67  0906040G0AABFBF  Colecal_Cap 600u                              9829
# 85  0905013F0AAADAD  Mag Cit_Tab 200mg                             4983
#
#     actual_cost  coefficient_of_deviation                 supplier  \
# 16     95559.03                  1.990893  Solgar Vitamin and Herb
# 31    257550.94                  1.590396  Solgar Vitamin and Herb
# 39      4366.25                  1.207822  Solgar Vitamin and Herb
# 67      7327.12                  1.825936  Solgar Vitamin and Herb
# 85      5945.04                  1.174160  Solgar Vitamin and Herb
#
#    tariff_category  pack_size_count bioequivalence         route
# 16            None               70           True  capsule.oral
# 31             3.0              418           True  capsule.oral
# 39            None               32           True  capsule.oral
# 67            None               28           True  capsule.oral
# 85            None               16           True   tablet.oral

# %%
df2.query('supplier == "Kyowa Kirin Ltd"')
# Out:
#            bnf_code                                  bnf_name  quantity  \
# 59  0604020K0AABMBM  Testosterone_Gel 2% (10mg per actuation)    225000
#
#     actual_cost  coefficient_of_deviation         supplier tariff_category  \
# 59     118205.8                  1.008506  Kyowa Kirin Ltd             3.0
#
#     pack_size_count bioequivalence          route
# 59               10           True  gel.cutaneous

# %% [markdown]
# # What about interesting outliers?
#
# So far, we've only focussed on presentations over a certain threshold of prescribing. The following is drugs with large cost discrepancy at Chemical level, and where highest cost-per-quantity (within 10% of maximum) comes up at less than 10 practices.

# %%
sql = """
WITH a AS (

SELECT
  b.chemical,
  SUBSTR(bnf_code,1,9) AS chemical_code,
  COUNT(*) AS count,
  sum(quantity) AS quantity,
  IEEE_DIVIDE(stddev_pop(IEEE_DIVIDE(actual_cost, quantity)), avg(IEEE_DIVIDE(actual_cost,quantity))) as coefficient_of_deviation,    
  MAX(IEEE_DIVIDE(actual_cost, quantity)) - MIN(IEEE_DIVIDE(actual_cost, quantity)) AS delta,
  MAX(IEEE_DIVIDE(actual_cost, quantity)) AS Max_cost,
  MIN(IEEE_DIVIDE(actual_cost, quantity)) AS Min_cost
  
FROM
  ebmdatalab.hscic.prescribing_2016_09_01 AS p
  LEFT JOIN (SELECT DISTINCT chemical, chemical_code FROM ebmdatalab.hscic.bnf) b ON SUBSTR(p.bnf_code,1,9) = b.chemical_code
  WHERE
    month = '2016-09-01'
    AND SUBSTR(bnf_code,1,2) < '18'
    AND NOT IS_INF(IEEE_DIVIDE(actual_cost, quantity))
GROUP BY
  chemical,
  chemical_code
ORDER BY
  delta DESC ),
  
p AS 
  (SELECT chemical_code, practice, sum(actual_cost) AS actual_cost, sum(quantity) as quantity, cost_per_quantity FROM (
              SELECT practice, SUBSTR(bnf_code,1,9) AS chemical_code, actual_cost, quantity, IEEE_DIVIDE(actual_cost, quantity) as cost_per_Quantity 
              FROM ebmdatalab.hscic.prescribing_2016_09_01
             ) GROUP BY chemical_code, cost_per_quantity, practice
             )

  
 SELECT  
  a.chemical,
  a.chemical_code,
  a.count,
  a.coefficient_of_deviation,
  a.delta,
  a.min_cost,
  a.max_cost,
  sum(p.quantity) AS Quant_at_max_cost,
  sum(p.actual_cost) AS Spend_at_max_cost,
  count (distinct p.practice) AS pracs_prescribing_at_max_cost
 FROM a
 LEFT JOIN  p 
       ON a.chemical_code = p.chemical_code AND p.cost_per_Quantity >= a.Max_cost*0.9
  
  WHERE IEEE_DIVIDE(a.delta,a.min_cost) >10
  GROUP BY 
    chemical,
    chemical_code,
    count,
    coefficient_of_deviation,
    delta,
    min_cost,
    max_cost
  
  HAVING pracs_prescribing_at_max_cost < 10
  ORDER BY Spend_at_max_cost DESC"""
df4 = pd.io.gbq.read_gbq(sql, project_id="ebmdatalab", verbose=False, dialect='standard')

# %%
display(HTML(df4.to_html(formatters={'delta': '£{:,.2f}'.format}, max_rows=10)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chemical</th>
#       <th>chemical_code</th>
#       <th>count</th>
#       <th>coefficient_of_deviation</th>
#       <th>delta</th>
#       <th>min_cost</th>
#       <th>max_cost</th>
#       <th>Quant_at_max_cost</th>
#       <th>Spend_at_max_cost</th>
#       <th>pracs_prescribing_at_max_cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sucralfate</td>
#       <td>0107010S0</td>
#       <td>10</td>
#       <td>0.965512</td>
#       <td>£236.44</td>
#       <td>1.192321</td>
#       <td>237.633167</td>
#       <td>63</td>
#       <td>14925.44</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Melatonin</td>
#       <td>0401010AD</td>
#       <td>16839</td>
#       <td>1.173136</td>
#       <td>£24.99</td>
#       <td>0.006000</td>
#       <td>24.997143</td>
#       <td>423</td>
#       <td>10012.24</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Insulin Human</td>
#       <td>0601011R0</td>
#       <td>32</td>
#       <td>0.610176</td>
#       <td>£1,614.21</td>
#       <td>1.420000</td>
#       <td>1615.630000</td>
#       <td>6</td>
#       <td>9393.50</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Morphine Sulfate</td>
#       <td>0407020Q0</td>
#       <td>71453</td>
#       <td>1.817894</td>
#       <td>£23.39</td>
#       <td>0.015625</td>
#       <td>23.408286</td>
#       <td>310</td>
#       <td>7230.02</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Sucralfate</td>
#       <td>0103030S0</td>
#       <td>555</td>
#       <td>1.521473</td>
#       <td>£12.96</td>
#       <td>0.023560</td>
#       <td>12.980313</td>
#       <td>424</td>
#       <td>5503.65</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>444</th>
#       <td>Lactulose</td>
#       <td>0106040G0</td>
#       <td>9112</td>
#       <td>2.378654</td>
#       <td>£0.29</td>
#       <td>0.004630</td>
#       <td>0.290000</td>
#       <td>2</td>
#       <td>0.58</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>445</th>
#       <td>Sterculia</td>
#       <td>0106010N0</td>
#       <td>3701</td>
#       <td>0.878734</td>
#       <td>£0.20</td>
#       <td>0.013833</td>
#       <td>0.210000</td>
#       <td>1</td>
#       <td>0.21</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>446</th>
#       <td>Sodium Picosulfate</td>
#       <td>0106020P0</td>
#       <td>4496</td>
#       <td>0.189338</td>
#       <td>£0.14</td>
#       <td>0.013583</td>
#       <td>0.150000</td>
#       <td>1</td>
#       <td>0.15</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>447</th>
#       <td>Zinc Oxide</td>
#       <td>1302020E0</td>
#       <td>6458</td>
#       <td>0.234210</td>
#       <td>£0.12</td>
#       <td>0.009280</td>
#       <td>0.130000</td>
#       <td>1</td>
#       <td>0.13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>448</th>
#       <td>Wool Alcohols</td>
#       <td>1302010Y0</td>
#       <td>1501</td>
#       <td>0.360299</td>
#       <td>£0.11</td>
#       <td>0.008710</td>
#       <td>0.120000</td>
#       <td>1</td>
#       <td>0.12</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
