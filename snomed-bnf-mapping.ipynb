# %%
import pandas as pd
import sqlite3
con = sqlite3.connect("dmd.db")

# %% [markdown]
# ## Restricted availability drugs
#
# "None" means the availablity is not restricted

# %%
sql = """
SELECT DESC from dmd_product
INNER JOIN

LOOKUP_AVAILABILITY_RESTRICTION
ON dmd_product.AVAIL_RESTRICTCD = CD
"""
df = pd.read_sql_query(sql, con)
df.groupby('DESC')['DESC'].count().sort_values()

# "Not available" means there are no AMPs for the specified VMP
# Out:
# DESC
# Extemp                       1
# Restricted Availability      32
# Individual Patient Supply    71
# Hospital Only                884
# Imported                     937
# Special                      12730
# Not available                21067
# None                         98416
# Name: DESC, dtype: int64

# %% [markdown]
# ## All drugs with special containers

# %%
# http://www.nhsbsa.nhs.uk/PrescriptionServices/Documents/PrescriptionServices/dmd_Implemention_Guide_(Primary_Care)_v1.0.pdf
sql = """
SELECT * from dmd_product
INNER JOIN AMP
  ON AMP.APID = DMDID
  OR AMP.VPID = DMDID
INNER JOIN AMPP
  ON AMPP.APID = AMP.APID
INNER JOIN REIMB_INFO
  ON AMPP.APPID = REIMB_INFO.APPID
  AND SPEC_CONTCD = 1
"""
special_containers = pd.read_sql_query(sql, con)

# %%
len(special_containers)
# Out:
# 90277

# %%
special_containers.head()
# Out:
#               DMDID         BNF_CODE       VPID  \
# 0         330726003  1106000P0AAAAAA  330726003
# 1   434711000001109  1106000P0BBAAAA  330726003
# 2         331126001  1202020L0AAAAAA  331126001
# 3  9433411000001107      21240000110  331126001
# 4         323733007  0501013B0AAAKAK  323733007
#
#                                   DISPLAY_NAME   EMA  PRES_STATCD  \
# 0                     Dorzolamide 2% eye drops     0            1
# 1         Trusopt 2% eye drops (Santen UK Ltd)  None            1
# 2             Sodium chloride 0.9% nasal drops     0            1
# 3  Sodium chloride 0.9% nasal drops (RX Farma)  None            1
# 4        Amoxicillin 250mg/5ml oral suspension     0            1
#
#    AVAIL_RESTRICTCD  product_type  NON_AVAILCO  concept_class  ...    \
# 0                 1             1          NaN              1  ...
# 1                 1             2          0.0              2  ...
# 2                 1             1          NaN              1  ...
# 3                 1             3          0.0              2  ...
# 4                 1             1          NaN              1  ...
#
#        DISCDT             APPID PX_CHRGS  DISP_FEES    BB  LTD_STAB  CAL_PACK  \
# 0        None  1384711000001109        1          1  None      None      None
# 1        None  1384711000001109        1          1  None      None      None
# 2        None  9433511000001106        1          1  None      None      None
# 3        None  9433511000001106        1          1  None      None      None
# 4  2007-05-08  1511211000001100        1          1  None      None      None
#
#    SPEC_CONTCD  DND  FP34D
# 0            1  NaN    NaN
# 1            1  NaN    NaN
# 2            1  NaN    NaN
# 3            1  NaN    NaN
# 4            1  NaN    NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Drugs by particular routes
#
# The first example just shows how to join the "route" table to the main table

# %%
sql = """
SELECT BNF_CODE, DISPLAY_NAME, DESC from dmd_product
INNER JOIN ONT
ON ONT.VPID = dmd_product.VPID
INNER JOIN LOOKUP_ONT_FORM_ROUTE
ON LOOKUP_ONT_FORM_ROUTE.CD = ONT.FORMCD
"""
df = pd.read_sql_query(sql, con)
df.head()
# Out:
#           BNF_CODE                   DISPLAY_NAME                         DESC
# 0  1311060I0AAABAB  Hydrogen peroxide 3% solution  solution.cutaneous
# 1  1311060I0AAABAB  Hydrogen peroxide 3% solution  mouthwash.oromucosal
# 2  1311060I0AAABAB  Hydrogen peroxide 3% solution  gargle.oromucosal
# 3  0308000B0AAAAAA  Benzoin compound tincture      solution.cutaneous
# 4  0308000B0AAAAAA  Benzoin compound tincture      vapourinhalation.inhalation

# %% [markdown]
# Here we only show thigs with a "form route" starting with `grocery`

# %%
sql = """
SELECT BNF_CODE, DISPLAY_NAME, DESC from dmd_product
INNER JOIN ONT
ON ONT.VPID = dmd_product.VPID
INNER JOIN LOOKUP_ONT_FORM_ROUTE
ON LOOKUP_ONT_FORM_ROUTE.CD = ONT.FORMCD
WHERE DESC LIKE 'grocery%'
"""
df = pd.read_sql_query(sql, con)
df.head()
# Out:
#   BNF_CODE  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
#                                                               DISPLAY_NAME  \
# 0  Barkat gluten free cream filled wafers (Flavour Not Specified)
# 1  Mrs Crimble's gluten free cheese crackers (Flavour Not Specified)
# 2  Mrs Crimble's gluten free rice cakes (Flavour Not Specified)
# 3  Orgran gluten free biscotti biscuits (Flavour Not Specified)
# 4  Orgran gluten free mini outback animals cookies (Flavour Not Specified)
#
#                 DESC
# 0  grocerysolid.oral
# 1  grocerysolid.oral
# 2  grocerysolid.oral
# 3  grocerysolid.oral
# 4  grocerysolid.oral

# %% [markdown]
# ## Drugs with more than one pack size
#
# First, we join only to VMPP (not via AMPs) which restricts us to generic equivalents.
#
# There are 5,971 VMPs with more than one pack size (that's 32% of all VMPS).

# %%
sql = """
SELECT 
  DMDID,
  BNF_CODE,
  DISPLAY_NAME, 
  COUNT(VMPP.QTYVAL) AS num_packsizes, 
  DESC AS unit_of_measure
FROM dmd_product
INNER JOIN VMPP
  ON VMPP.VPID = DMDID
INNER JOIN LOOKUP_UNIT_OF_MEASURE
  ON LOOKUP_UNIT_OF_MEASURE.CD = VMPP.QTY_UOMCD
GROUP BY DISPLAY_NAME
HAVING count(VMPP.QTYVAL) = 1
order by count(VMPP.QTYVAL) DESC
"""
df2 = pd.read_sql_query(sql, con)
pd.set_option('display.max_colwidth', -1)
df2.head(10)
# Out:
#                DMDID         BNF_CODE  \
# 0  26245611000001101  None
# 1  324881002          0503010E0AAABAB
# 2  324880001          0503010E0AAAAAA
# 3  413382007          0503010Z0AAAAAA
# 4  29767011000001106  1001030V0AAACAC
# 5  21704711000001107  1001030V0AAABAB
# 6  11762011000001101  1001030V0AAAAAA
# 7  319794009          0209000W0AAAAAA
# 8  19524511000001101  0803042T0AAAAAA
# 9  7276711000001101   None
#
#                                                                           DISPLAY_NAME  \
# 0  5-aminolaevulinic acid 78mg/g gel
# 1  Abacavir 20mg/ml oral solution sugar free
# 2  Abacavir 300mg tablets
# 3  Abacavir 600mg / Lamivudine 300mg tablets
# 4  Abatacept 125mg/1ml solution for injection pre-filled disposable devices
# 5  Abatacept 125mg/1ml solution for injection pre-filled syringes
# 6  Abatacept 250mg powder for solution for infusion vials
# 7  Abciximab 10mg/5ml solution for injection vials
# 8  Abiraterone 250mg tablets
# 9  Absorbable catgut chromic suture 2gauge 75cm length with 16mm curved cutting needle
#
#    num_packsizes                  unit_of_measure
# 0  1              gram
# 1  1              ml
# 2  1              tablet
# 3  1              tablet
# 4  1              pre-filled disposable injection
# 5  1              pre-filled disposable injection
# 6  1              vial
# 7  1              vial
# 8  1              tablet
# 9  1              suture

# %% [markdown]
# Drill down into gluten free bread:

# %%
sql = """SELECT 
  DMDID,
  BNF_CODE,
  DISPLAY_NAME, 
  VMPP.QTYVAL, 
  DESC AS unit_of_measure
FROM dmd_product
INNER JOIN VMPP
  ON VMPP.VPID = DMDID
INNER JOIN LOOKUP_UNIT_OF_MEASURE
  ON LOOKUP_UNIT_OF_MEASURE.CD = VMPP.QTY_UOMCD
WHERE DMDID = '328664004'
"""

df2 = pd.read_sql_query(sql, con)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', 40)
df2.head(5)
# Out:
#        DMDID         BNF_CODE       DISPLAY_NAME  QTYVAL unit_of_measure
# 0  328664004  0904010H0AAAAAA  Gluten free bread  450.0   gram
# 1  328664004  0904010H0AAAAAA  Gluten free bread  150.0   gram
# 2  328664004  0904010H0AAAAAA  Gluten free bread  250.0   gram
# 3  328664004  0904010H0AAAAAA  Gluten free bread  456.0   gram
# 4  328664004  0904010H0AAAAAA  Gluten free bread  612.0   gram

# %% [markdown]
# Pack size is not the only variation. There are also things like colour, flavour, etc.
#
# If we join on AMP tables, we get every pack size combined with all other variations:

# %%
# This counts all variants/flavours of all sizes of actual packs

sql = """SELECT count(QTYVAL) as num_pack_sizes, BNF_CODE, DMDID, DISPLAY_NAME from dmd_product
INNER JOIN AMP
  ON AMP.APID = DMDID
  OR AMP.VPID = DMDID
INNER JOIN AMPP
  ON AMPP.APID = AMP.APID
INNER JOIN VMPP
ON AMPP.VPPID = VMPP.VPPID 
GROUP BY DMDID ORDER BY num_pack_sizes DESC
"""
df2 = pd.read_sql_query(sql, con)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', 40)
df2.head(5)
# Out:
#    num_pack_sizes BNF_CODE              DMDID  \
# 0  5656            None     33501811000001106
# 1  4467            None     33502211000001103
# 2  4282            None     33508511000001103
# 3  4108            None     33507811000001104
# 4  4092            None     33508611000001104
#
#                                                                  DISPLAY_NAME
# 0  Lymphoedema garments below knee closed toe
# 1  Lymphoedema garments below knee open toe
# 2  Lymphoedema garments tights/panty closed toe
# 3  Lymphoedema garments thigh length closed toe with silicone top/band/border
# 4  Lymphoedema garments tights/panty open toe

# %% [markdown]
# If we drill down into these lympoedema socks, we can see all the variants are brand vs. size vs. colour:

# %%
sql = """
SELECT AMP.DESC, QTYVAL as num_pack_sizes, LOOKUP_UNIT_OF_MEASURE.DESC AS unit_of_measure,BNF_CODE, DMDID from dmd_product
INNER JOIN AMP
  ON AMP.APID = DMDID
  OR AMP.VPID = DMDID
INNER JOIN AMPP
  ON AMPP.APID = AMP.APID
INNER JOIN VMPP
  ON AMPP.VPPID = VMPP.VPPID 
INNER JOIN LOOKUP_UNIT_OF_MEASURE
  ON LOOKUP_UNIT_OF_MEASURE.CD = VMPP.QTY_UOMCD
WHERE DMDID = '33501811000001106'"""

pd.read_sql_query(sql, con)
# Out:
#                                                                                                                            DESC  \
# 0     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment standard small Sand (Activa Healthcare Ltd)
# 1     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment standard medium Sand (Activa Healthcare Ltd)
# 2     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment standard large Sand (Activa Healthcare Ltd)
# 3     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment standard extra large Sand (Activa Healthcare Ltd)
# 4     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite small Sand (Activa Healthcare Ltd)
# 5     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite medium Sand (Activa Healthcare Ltd)
# 6     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite large Sand (Activa Healthcare Ltd)
# 7     ActiLymph class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite extra large Sand (Activa Healthcare Ltd)
# 8     ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard small Sand (Activa Healthcare Ltd)
# 9     ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard medium Sand (Activa Healthcare Ltd)
# 10    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard large Sand (Activa Healthcare Ltd)
# 11    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard extra large Sand (Activa Healthcare Ltd)
# 12    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite small Sand (Activa Healthcare Ltd)
# 13    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite medium Sand (Activa Healthcare Ltd)
# 14    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite large Sand (Activa Healthcare Ltd)
# 15    ActiLymph class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite extra large Sand (Activa Healthcare Ltd)
# 16    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size I Sand (BSN medical Ltd)
# 17    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size II Sand (BSN medical Ltd)
# 18    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size III Sand (BSN medical Ltd)
# 19    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size IV Sand (BSN medical Ltd)
# 20    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size V Sand (BSN medical Ltd)
# 21    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment petite size VI Sand (BSN medical Ltd)
# 22    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size I Sand (BSN medical Ltd)
# 23    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size II Sand (BSN medical Ltd)
# 24    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size III Sand (BSN medical Ltd)
# 25    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size IV Sand (BSN medical Ltd)
# 26    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size V Sand (BSN medical Ltd)
# 27    Jobst Opaque class 1 (18-21mmHg) below knee closed toe lymphoedema garment regular size VI Sand (BSN medical Ltd)
# 28    Jobst Opaque class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite size I Sand (BSN medical Ltd)
# 29    Jobst Opaque class 2 (23-32mmHg) below knee closed toe lymphoedema garment petite size II Sand (BSN medical Ltd)
# ...                                                                                                                ...
# 5626  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size IV Blueberry (Juzo UK Ltd)
# 5627  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size IV Poppy seed (Juzo UK Ltd)
# 5628  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size V Blueberry (Juzo UK Ltd)
# 5629  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size V Poppy seed (Juzo UK Ltd)
# 5630  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size VI Blueberry (Juzo UK Ltd)
# 5631  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment extra short size VI Poppy seed (Juzo UK Ltd)
# 5632  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size I Blueberry (Juzo UK Ltd)
# 5633  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size I Poppy seed (Juzo UK Ltd)
# 5634  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size II Blueberry (Juzo UK Ltd)
# 5635  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size II Poppy seed (Juzo UK Ltd)
# 5636  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size III Blueberry (Juzo UK Ltd)
# 5637  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size III Poppy seed (Juzo UK Ltd)
# 5638  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size IV Blueberry (Juzo UK Ltd)
# 5639  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size IV Poppy seed (Juzo UK Ltd)
# 5640  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size V Blueberry (Juzo UK Ltd)
# 5641  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size V Poppy seed (Juzo UK Ltd)
# 5642  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size VI Blueberry (Juzo UK Ltd)
# 5643  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment short size VI Poppy seed (Juzo UK Ltd)
# 5644  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size I Blueberry (Juzo UK Ltd)
# 5645  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size I Poppy seed (Juzo UK Ltd)
# 5646  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size II Blueberry (Juzo UK Ltd)
# 5647  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size II Poppy seed (Juzo UK Ltd)
# 5648  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size III Blueberry (Juzo UK Ltd)
# 5649  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size III Poppy seed (Juzo UK Ltd)
# 5650  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size IV Blueberry (Juzo UK Ltd)
# 5651  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size IV Poppy seed (Juzo UK Ltd)
# 5652  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size V Blueberry (Juzo UK Ltd)
# 5653  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size V Poppy seed (Juzo UK Ltd)
# 5654  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size VI Blueberry (Juzo UK Ltd)
# 5655  Juzo Dynamic class 2 (23-32mmHg) below knee closed toe lymphoedema garment standard size VI Poppy seed (Juzo UK Ltd)
#
#       num_pack_sizes unit_of_measure BNF_CODE              DMDID
# 0     2.0             device          None     33501811000001106
# 1     2.0             device          None     33501811000001106
# 2     2.0             device          None     33501811000001106
# 3     2.0             device          None     33501811000001106
# 4     2.0             device          None     33501811000001106
# 5     2.0             device          None     33501811000001106
# 6     2.0             device          None     33501811000001106
# 7     2.0             device          None     33501811000001106
# 8     2.0             device          None     33501811000001106
# 9     2.0             device          None     33501811000001106
# 10    2.0             device          None     33501811000001106
# 11    2.0             device          None     33501811000001106
# 12    2.0             device          None     33501811000001106
# 13    2.0             device          None     33501811000001106
# 14    2.0             device          None     33501811000001106
# 15    2.0             device          None     33501811000001106
# 16    2.0             device          None     33501811000001106
# 17    2.0             device          None     33501811000001106
# 18    2.0             device          None     33501811000001106
# 19    2.0             device          None     33501811000001106
# 20    2.0             device          None     33501811000001106
# 21    2.0             device          None     33501811000001106
# 22    2.0             device          None     33501811000001106
# 23    2.0             device          None     33501811000001106
# 24    2.0             device          None     33501811000001106
# 25    2.0             device          None     33501811000001106
# 26    2.0             device          None     33501811000001106
# 27    2.0             device          None     33501811000001106
# 28    2.0             device          None     33501811000001106
# 29    2.0             device          None     33501811000001106
# ...   ...                ...           ...                   ...
# 5626  2.0             device          None     33501811000001106
# 5627  2.0             device          None     33501811000001106
# 5628  2.0             device          None     33501811000001106
# 5629  2.0             device          None     33501811000001106
# 5630  2.0             device          None     33501811000001106
# 5631  2.0             device          None     33501811000001106
# 5632  2.0             device          None     33501811000001106
# 5633  2.0             device          None     33501811000001106
# 5634  2.0             device          None     33501811000001106
# 5635  2.0             device          None     33501811000001106
# 5636  2.0             device          None     33501811000001106
# 5637  2.0             device          None     33501811000001106
# 5638  2.0             device          None     33501811000001106
# 5639  2.0             device          None     33501811000001106
# 5640  2.0             device          None     33501811000001106
# 5641  2.0             device          None     33501811000001106
# 5642  2.0             device          None     33501811000001106
# 5643  2.0             device          None     33501811000001106
# 5644  2.0             device          None     33501811000001106
# 5645  2.0             device          None     33501811000001106
# 5646  2.0             device          None     33501811000001106
# 5647  2.0             device          None     33501811000001106
# 5648  2.0             device          None     33501811000001106
# 5649  2.0             device          None     33501811000001106
# 5650  2.0             device          None     33501811000001106
# 5651  2.0             device          None     33501811000001106
# 5652  2.0             device          None     33501811000001106
# 5653  2.0             device          None     33501811000001106
# 5654  2.0             device          None     33501811000001106
# 5655  2.0             device          None     33501811000001106
#
# [5656 rows x 5 columns]

# %% [markdown]
# # Generics where brands are not necessarily bioequivalent
#
# These are brands which should not be prescribed generically.

# %%
sql = """
SELECT DMDID, BNF_CODE, DISPLAY_NAME FROM dmd_product
INNER JOIN VMPP
  ON VMPP.VPID = DMDID
INNER JOIN VMP
  ON VMPP.VPID = VMP.VPID
WHERE VMP.PRES_STATCD = 6"""
df = pd.read_sql_query(sql, con)
df.head(20)
# Out:
#         DMDID         BNF_CODE                                  DISPLAY_NAME
# 0   322864007  0408010C0AAACAC  Carbamazepine 200mg tablets
# 1   322865008  0408010C0AAADAD  Carbamazepine 400mg tablets
# 2   321730000  0402030K0AAACAC  Lithium carbonate 250mg tablets
# 3   319184008  0206020C0AAAVAV  Diltiazem 180mg modified-release capsules
# 4   327097004  0802020T0AAAAAA  Tacrolimus 5mg capsules
# 5   322865008  0408010C0AAADAD  Carbamazepine 400mg tablets
# 6   322943009  0408010Q0AAADAD  Phenytoin sodium 25mg capsules
# 7   322944003  0408010Q0AAAPAP  Phenytoin sodium 50mg capsules
# 8   319187001  0206020C0AAAXAX  Diltiazem 200mg modified-release capsules
# 9   319277008  0206020R0AAARAR  Nifedipine 20mg modified-release tablets
# 10  322916004  0408010N0AAAJAJ  Phenobarbital 30mg tablets
# 11  319277008  0206020R0AAARAR  Nifedipine 20mg modified-release tablets
# 12  319186005  0206020C0AAAWAW  Diltiazem 240mg modified-release capsules
# 13  322883000  0408010C0AAAGAG  Carbamazepine 200mg modified-release tablets
# 14  322917008  0408010N0AAALAL  Phenobarbital 60mg tablets
# 15  322934000  0408010Q0AAAGAG  Phenytoin sodium 100mg tablets
# 16  319276004  0206020R0AAAPAP  Nifedipine 60mg modified-release tablets
# 17  322945002  0408010Q0AAAAAA  Phenytoin sodium 100mg capsules
# 18  319198000  0206020C0AABABA  Diltiazem 360mg modified-release capsules
# 19  319277008  0206020R0AAARAR  Nifedipine 20mg modified-release tablets

# %%
df[df.BNF_CODE.str.contains("0302000C0")]
# Out:
#                  DMDID         BNF_CODE  \
# 56   408063002          0302000C0AABFBF
# 57   408061000          0302000C0AABEBE
# 104  10621011000001101  0302000C0AABVBV
# 105  10621111000001100  0302000C0AABWBW
#
#                                           DISPLAY_NAME
# 56   Beclometasone 100micrograms/dose inhaler CFC free
# 57   Beclometasone 50micrograms/dose inhaler CFC free
# 104  Beclometasone 200micrograms/dose inhaler CFC free
# 105  Beclometasone 250micrograms/dose inhaler CFC free

# %% [markdown]
# On this account, the following is OK to include:
#
# ```
# Qvar 100_Autohaler 100mcg (200 D),0302000C0BJADBH
# Qvar 100 E-Breathe_Inha 100mcg (200 D),0302000C0BJAFBH
# Qvar 50_Autohaler 50mcg (200 D),0302000C0BJACBG
# Qvar 50 E-Breathe_Inha 50mcg (200 D),0302000C0BJAEBG
#
# ```
#
# But these are not:
#
# ```
# Qvar 100_Inha 100mcg (200 D),0302000C0BJABBF
# Qvar 50_Inha 50mcg (200 D),0302000C0BJAABE
#
#
# ```

# %%
# Make a new BNF table which can be used in PPP calculations, which includes (for generics)
# bnf_code, dmdid, bioequivalence, min_pack_size, count_pack_size, special_containers, supplier

# LOOKUP_DT_PAYMENT_CATEGORY - DT category
sql = """
WITH foo AS (
SELECT
  BNF_CODE AS bnf_code, 
  DMDID AS dmd_id, 
  DISPLAY_NAME AS name,
  product_type AS product_type, -- generic, brand, branded generic
  VMP.PRES_STATCD != 6 AS bioequivalence,
  MIN(VMPP.QTYVAL) AS min_pack_size,
  COUNT(VMPP.QTYVAL) AS pack_size_count,
  LOOKUP_ONT_FORM_ROUTE.DESC as route,
  LOOKUP_UNIT_OF_MEASURE.DESC AS dose_unit,
  LOOKUP_DT_PAYMENT_CATEGORY.DESC AS tariff_category

FROM dmd_product
INNER JOIN VMPP
  ON VMPP.VPID = DMDID
INNER JOIN VMP
  ON VMPP.VPID = VMP.VPID
INNER JOIN ONT
  ON ONT.VPID = VMP.VPID
INNER JOIN LOOKUP_ONT_FORM_ROUTE
  ON LOOKUP_ONT_FORM_ROUTE.CD = ONT.FORMCD
INNER JOIN AMP
  ON AMP.APID = DMDID
  OR AMP.VPID = DMDID
INNER JOIN LOOKUP_UNIT_OF_MEASURE
  ON LOOKUP_UNIT_OF_MEASURE.CD = VMPP.QTY_UOMCD
INNER JOIN LOOKUP_DT_PAYMENT_CATEGORY
  ON LOOKUP_DT_PAYMENT_CATEGORY.CD = dmd_product.tariff_category
WHERE bnf_code IS NOT NULL
GROUP BY bnf_code)

select * from foo 

""" 
df = pd.read_sql_query(sql, con)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', 40)
df.to_csv("bnf_extended.csv")

# %%
df[df.bnf_code == '1202020L0AAAAAA']
# Out:
# Empty DataFrame
# Columns: [bnf_code, dmd_id, name, bioequivalence, min_pack_size, pack_size_count, special_container, supplier, dose_unit]
# Index: []

# %%
df[df.special_container != 1]
# Out:
#              bnf_code             dmd_id  \
# 0                None   9446311000001108
# 30        20030100020          334277004
# 34        20030100150   3137111000001109
# 35        20030100165   3137211000001103
# 38        20040200420   3332811000001108
# 39        20060000300          335285000
# 41        20080000110   3431711000001100
# 42        20120000100   3463011000001108
# 44        20120000120   3457011000001108
# 45        20120000205   3506411000001101
# 47        20120000220   3457111000001109
# 53        21010800100   3457211000001103
# 61        21010900400   3481111000001106
# 62        21010900410   3481511000001102
# 63        21010900420   3481711000001107
# 64        21010900425   3485211000001102
# 66        21010900440   3481211000001100
# 67        21010900445   3481611000001103
# 68        21010900450   7500011000001102
# 71        21011100200   7316611000001105
# 101       21020001040  15632511000001105
# 145       21070410110   7279111000001105
# 146       21070410111   7279011000001109
# 147       21070410120   7279411000001100
# 148       21070410121   7279311000001107
# 149       21070410131  24386711000001107
# 150       21070420110   7279211000001104
# 151       21070420120   7279511000001101
# 152       21070420130   7279611000001102
# 153       21070510110   7279811000001103
# ...               ...                ...
# 5726  1502010R0AAAAAA          334197002
# 5727  1502010R0AAABAB          334198007
# 5728  1502010R0AAADAD          334201002
# 5729  1502010R0AAAEAE          334199004
# 5730  1502010S0AAACAC   4748111000001103
# 5732  1502010S0AAAIAI  11416011000001109
# 5733  1502010S0AAAJAJ  24610311000001104
# 5734  1502010U0AAAAAA   4957611000001102
# 5735  1502010V0AAAAAA          334213007
# 5736  1502010V0AAABAB          334212002
# 5737  1502010V0AAACAC          334211009
# 5740  1502010Z0AAAAAA  17071111000001101
# 5741  1502010Z0AAABAB  17071211000001107
# 5742  1502010Z0AAACAC  17071311000001104
# 5743  180400000AABABA          358181007
# 5744  190100000AAAAAA  20419011000001106
# 5745  190100000AAABAB  15648311000001102
# 5746  190201000AABLBL  22361611000001103
# 5747  1902070A0AAAAAA          323349006
# 5748  1902070C0AAAAAA          317871008
# 5749  1902070D0AAAAAA          317878002
# 5750  1902070E0AAABAB   3818011000001108
# 5751  1902070E0AAAHAH  10633711000001101
# 5752  1902070E0AAAIAI          350079007
# 5753  1902070E0AAAMAM  22437011000001103
# 5754  1902070M0AAAAAA          323351005
# 5755  1902070Q0AAAAAA   4062511000001102
# 5760  190400000AAUJUJ  17870811000001101
# 5761  190500000AAACAC   8967211000001109
# 5762  190500000AABKBK  15160111000001106
#
#                                                    name  bioequivalence  \
# 0     Hydrogel sheet without adhesive border 5cm x 6...               1
# 30                          Multiple pack dressing No 1               1
# 34               Sterile dressing pack specification 10               1
# 35    Sterile dressing pack with non-woven pads spec...               1
# 38          Chlorhexidine gauze dressing BP 10cm x 10cm               1
# 39              Latex foam adhesive 22.5cm x 45cm x 7mm               1
# 41    Belladonna adhesive plaster BP 1980 28cm x 17.5cm               1
# 42    Gauze swab type 13 light BP 1988 8ply non-ster...               1
# 44    Filmated gauze swab BP 1988 8ply non-sterile 1...               1
# 45    Non-woven fabric swab 4ply non-sterile 10cm x ...               1
# 47    Filmated non-woven fabric swab 8ply non-steril...               1
# 53                                           Finger cot               1
# 61    Hypodermic U100 insulin syringe sterile single...               1
# 62    Hypodermic U100 insulin syringe sterile single...               1
# 63    Hypodermic U100 insulin syringe sterile single...               1
# 64    Hypodermic needle sterile single use 0.5mm/25g...               1
# 66    Hypodermic U100 insulin syringe sterile single...               1
# 67    Hypodermic U100 insulin syringe sterile single...               1
# 68    Hypodermic U100 insulin syringe sterile single...               1
# 71                                       Breast shields               1
# 101   Hypodermic U100 insulin syringe sterile single...               1
# 145   Compression hosiery class I below knee stockin...               1
# 146   Compression hosiery class I below knee stockin...               1
# 147   Compression hosiery class I thigh length stock...               1
# 148   Compression hosiery class I thigh length stock...               1
# 149   Compression hosiery class I thigh length stock...               1
# 150   Compression hosiery class I below knee stockin...               1
# 151   Compression hosiery class I thigh length stock...               1
# 152   Compression hosiery class I thigh length stock...               1
# 153   Compression hosiery class II anklet circular k...               1
# ...                                                 ...             ...
# 5726  Ropivacaine 20mg/10ml solution for injection a...               1
# 5727  Ropivacaine 75mg/10ml solution for injection a...               1
# 5728              Ropivacaine 400mg/200ml infusion bags               1
# 5729  Ropivacaine 100mg/10ml solution for injection ...               1
# 5730  Prilocaine 200mg/20ml solution for injection v...               1
# 5732  Prilocaine 54mg/1.8ml / Felypressin 0.054units...               1
# 5733  Prilocaine 66mg/2.2ml / Felypressin 0.066units...               1
# 5734  Procaine hydrochloride 40mg/2ml solution for i...               1
# 5735  Levobupivacaine 25mg/10ml solution for injecti...               1
# 5736  Levobupivacaine 50mg/10ml solution for injecti...               1
# 5737  Levobupivacaine 75mg/10ml solution for injecti...               1
# 5740  Bupivacaine 100mg/100ml (0.1%) / Fentanyl 200m...               1
# 5741  Bupivacaine 250mg/250ml (0.1%) / Fentanyl 500m...               1
# 5742  Bupivacaine 500mg/500ml (0.1%) / Fentanyl 1mg/...               1
# 5743  Pentagastrin 500micrograms/2ml solution for in...               1
# 5744   Ethanol 100% solution for injection 5ml ampoules               1
# 5745   Ethanol 100% solution for injection 2ml ampoules               1
# 5746  Procaine hydrochloride 500mg/500ml solution fo...               1
# 5747  Acetylcysteine 2g/10ml solution for infusion a...               1
# 5748  Dicobalt edetate 300mg/20ml solution for injec...               1
# 5749  Dimercaprol 100mg/2ml solution for injection a...               1
# 5750                   Activated charcoal 300mg tablets               1
# 5751                  Activated charcoal 200mg capsules               1
# 5752  Activated charcoal 5g effervescent granules sa...               1
# 5753                  Activated charcoal 300mg capsules               1
# 5754                         L-Methionine 250mg tablets               1
# 5755  Naloxone 400micrograms/1ml solution for inject...               1
# 5760               Magnesium oxide heavy 100mg capsules               1
# 5761                    Ammonium sulfate 500mg capsules               1
# 5762                     Ammonium sulfate 500mg tablets               1
#
#       min_pack_size  pack_size_count  special_container  \
# 0               1.0           200807                NaN
# 30              1.0                4                NaN
# 34              1.0               44                NaN
# 35              1.0               12                NaN
# 38              1.0                4                NaN
# 39              4.0                1                NaN
# 41              1.0                4                NaN
# 42            100.0                8                NaN
# 44            100.0                1                NaN
# 45             50.0               20                NaN
# 47            100.0                1                NaN
# 53             10.0                4                NaN
# 61             10.0                1                NaN
# 62             10.0               18                NaN
# 63             10.0               18                NaN
# 64            100.0                5                NaN
# 66             10.0                1                NaN
# 67             10.0                6                NaN
# 68             10.0                6                NaN
# 71              2.0                2                NaN
# 101            10.0                4                NaN
# 145             2.0              165                NaN
# 146             2.0               12                NaN
# 147             2.0              128                NaN
# 148             2.0               16                NaN
# 149             2.0                2                NaN
# 150             2.0                3                NaN
# 151             2.0                3                NaN
# 152             2.0                2                NaN
# 153             2.0               11                NaN
# ...             ...              ...                ...
# 5726            5.0                6                NaN
# 5727            5.0                6                NaN
# 5728            5.0                6                NaN
# 5729            5.0                6                NaN
# 5730            5.0                1                NaN
# 5732          100.0                1                NaN
# 5733          100.0                1                NaN
# 5734           10.0                3                NaN
# 5735           10.0                1                NaN
# 5736           10.0                1                NaN
# 5737           10.0                1                NaN
# 5740            1.0                9                NaN
# 5741            1.0                6                NaN
# 5742            1.0                6                NaN
# 5743            5.0                1                NaN
# 5744           10.0                2                NaN
# 5745           10.0                3                NaN
# 5746            1.0                4                NaN
# 5747           10.0                4                NaN
# 5748            6.0                3                NaN
# 5749           10.0                3                NaN
# 5750           50.0                9                NaN
# 5751           30.0                1                NaN
# 5752            5.0                1                NaN
# 5753           50.0                4                NaN
# 5754          200.0                8                NaN
# 5755            1.0               48                NaN
# 5760            1.0                1                NaN
# 5761            1.0                1                NaN
# 5762            1.0                1                NaN
#
#                                     supplier  dose_unit
# 0                      Activa Healthcare Ltd   dressing
# 30                        Synergy Health Plc       pack
# 34                         CliniSupplies Ltd       pack
# 35                         CliniSupplies Ltd       pack
# 38             Smith & Nephew Healthcare Ltd   dressing
# 39             Smith & Nephew Healthcare Ltd     device
# 41       Cuxson Gerrard & Co (Dressings) Ltd    plaster
# 42                           BSN medical Ltd       swab
# 44                        Synergy Health Plc       swab
# 45                        Synergy Health Plc       swab
# 47           Systagenix Wound Management Ltd       swab
# 53                            Bray Group Ltd     device
# 61                          Owen Mumford Ltd    syringe
# 62                             Terumo UK Ltd    syringe
# 63                             Terumo UK Ltd    syringe
# 64              Covidien (UK) Commercial Ltd     needle
# 66                  Becton, Dickinson UK Ltd    syringe
# 67                       B.Braun Medical Ltd    syringe
# 68                       B.Braun Medical Ltd    syringe
# 71                            Bray Group Ltd     device
# 101                      B.Braun Medical Ltd    syringe
# 145             Covidien (UK) Commercial Ltd   stocking
# 146                           Credenhill Ltd   stocking
# 147                    SSL International Plc   stocking
# 148                           Credenhill Ltd   stocking
# 149                             E Sallis Ltd   stocking
# 150                           Credenhill Ltd   stocking
# 151                             E Sallis Ltd   stocking
# 152                             E Sallis Ltd   stocking
# 153                    Activa Healthcare Ltd   stocking
# ...                                      ...        ...
# 5726                                    AMCo    ampoule
# 5727                      AstraZeneca UK Ltd    ampoule
# 5728                                    AMCo        bag
# 5729                      AstraZeneca UK Ltd    ampoule
# 5730                      AstraZeneca UK Ltd       vial
# 5732                            Dentsply Ltd  cartridge
# 5733                            Dentsply Ltd  cartridge
# 5734               A A H Pharmaceuticals Ltd    ampoule
# 5735                              AbbVie Ltd    ampoule
# 5736                              AbbVie Ltd    ampoule
# 5737                              AbbVie Ltd    ampoule
# 5740                           Special Order        bag
# 5741                                    AMCo        bag
# 5742                                    AMCo        bag
# 5743            Alliance Pharmaceuticals Ltd    ampoule
# 5744               A A H Pharmaceuticals Ltd    ampoule
# 5745               A A H Pharmaceuticals Ltd    ampoule
# 5746                           Special Order     bottle
# 5747                        Phoenix Labs Ltd    ampoule
# 5748               A A H Pharmaceuticals Ltd    ampoule
# 5749  Alliance Healthcare (Distribution) Ltd    ampoule
# 5750                 J.L.Bragg (Ipswich) Ltd     tablet
# 5751              Galpharm International Ltd    capsule
# 5752             Concord Pharmaceuticals Ltd     sachet
# 5753                 J.L.Bragg (Ipswich) Ltd    capsule
# 5754                          UCB Pharma Ltd     tablet
# 5755               A A H Pharmaceuticals Ltd    ampoule
# 5760                           Special Order    capsule
# 5761                           Special Order    capsule
# 5762                           Special Order     tablet
#
# [4518 rows x 9 columns]

# %%
sql = "select * from dmd_product where bnf_code like '0208020W0BBABA0'"
df2 = pd.read_sql_query(sql, con)

# %%
df2[df2.BNF_CODE == '0208020W0BBABA0']
# Out:
#                DMDID         BNF_CODE              VPID  \
# 0  10186011000001104  0208020W0BBABA0  3475111000001102
#
#                                              DISPLAY_NAME   EMA  PRES_STATCD  \
# 0  CoaguChek XS PT testing strips (Roche Diagnostics Ltd)  None  1
#
#    AVAIL_RESTRICTCD  product_type  NON_AVAILCO  concept_class  NURSE_F  \
# 0  1                 2             0            2              1
#
#    DENT_F PROD_ORDER_NO  SCHED_1  SCHED_2  PADM  FP10_MDA  ACBS  assort_flav  \
# 0  0       None          0        0        0     0         0     0
#
#    CATCD  tariff_category
# 0  0      8

# %%
df[df.bnf_code == '0208020W0BBABA0']
# Out:
# Empty DataFrame
# Columns: [bnf_code, dmd_id, name, bioequivalence, min_pack_size, pack_size_count, special_container, supplier]
# Index: []

# %%
sql = """
SELECT
  *
FROM dmd_product
INNER JOIN VMPP
  ON VMPP.VPID = DMDID
INNER JOIN VMP
  ON VMPP.VPID = VMP.VPID
INNER JOIN AMP
  ON AMP.APID = DMDID
  OR AMP.VPID = DMDID
INNER JOIN AMPP
  ON AMPP.APID = AMP.APID
INNER JOIN REIMB_INFO
  ON AMPP.APPID = REIMB_INFO.APPID
INNER JOIN LOOKUP_SUPPLIER
  ON LOOKUP_SUPPLIER.CD = AMP.SUPPCD
WHERE BNF_CODE = '0208020W0BBABA0'
"""
pd.read_sql_query(sql, con)
# Out:
# Empty DataFrame
# Columns: [DMDID, BNF_CODE, VPID, DISPLAY_NAME, EMA, PRES_STATCD, AVAIL_RESTRICTCD, product_type, NON_AVAILCO, concept_class, NURSE_F, DENT_F, PROD_ORDER_NO, SCHED_1, SCHED_2, PADM, FP10_MDA, ACBS, assort_flav, CATCD, tariff_category, VPPID, INVALID, NM, ABBREVNM, VPID, QTYVAL, QTY_UOMCD, COMBPACKCD]
# Index: []
#
# [0 rows x 29 columns]

# %%
df3[df3.BNF_CODE == '0208020W0BBABA0']
# Out:
# Empty DataFrame
# Columns: [DMDID, BNF_CODE, VPID, DISPLAY_NAME, EMA, PRES_STATCD, AVAIL_RESTRICTCD, product_type, NON_AVAILCO, concept_class, NURSE_F, DENT_F, PROD_ORDER_NO, SCHED_1, SCHED_2, PADM, FP10_MDA, ACBS, assort_flav, CATCD, tariff_category, VPPID, INVALID, NM, ABBREVNM, VPID, QTYVAL, QTY_UOMCD, COMBPACKCD, VPID, VPIDDT, VPIDPREV, VTMID, INVALID, NM, ABBREVNM, BASISCD, NMDT, NMPREV, BASIS_PREVCD, NMCHANGECD, COMBPRODCD, PRES_STATCD, SUG_F, GLU_F, PRES_F, CFC_F, NON_AVAILCD, NON_AVAILDT, DF_INDCD, UDFS, UDFS_UOMCD, UNIT_DOSE_UOMCD, APID, INVALID, VPID, NM, ABBREVNM, DESC, NMDT, NM_PREV, SUPPCD, LIC_AUTHCD, LIC_AUTH_PREVCD, LIC_AUTHCHANGECD, LIC_AUTHCHANGEDT, COMBPRODCD, FLAVOURCD, EMA, PARALLEL_IMPORT, AVAIL_RESTRICTCD, APPID, INVALID, NM, ABBREVNM, VPPID, APID, COMBPACKCD, LEGAL_CATCD, SUBP, DISCCD, DISCDT, APPID, PX_CHRGS, DISP_FEES, BB, LTD_STAB, CAL_PACK, SPEC_CONTCD, DND, FP34D, CD, CDDT, CDPREV, INVALID, DESC]
# Index: []
#
# [0 rows x 96 columns]
